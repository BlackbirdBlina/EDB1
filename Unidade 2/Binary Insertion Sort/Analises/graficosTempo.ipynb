# %% [markdown]
# ### Tabela de dados base

# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("Tabela.csv")
df
# Out:
#     Unnamed: 0     tempo  comparações      trocas              Algoritmo  \
# 0            0  0.000211         9976      500499  Binary Insertion Sort
# 1            1  0.000368       500499      500499         Insertion Sort
# 2            2  0.019323       133616    50004999  Binary Insertion Sort
# 3            3  0.031554     50004999    50004999         Insertion Sort
# 4            4  0.082745       287232   200009999  Binary Insertion Sort
# 5            5  0.125444    200009999   200009999         Insertion Sort
# 6            6  0.184324       447232   450014999  Binary Insertion Sort
# 7            7  0.283805    450014999   450014999         Insertion Sort
# 8            8  0.337634       614464   800019999  Binary Insertion Sort
# 9            9  0.548989    800019999   800019999         Insertion Sort
# 10          10  0.502566       784464  1250024999  Binary Insertion Sort
# 11          11  0.838829   1250024999  1250024999         Insertion Sort
# 12          12  0.745582       954464  1800029999  Binary Insertion Sort
# 13          13  1.268749   1800029999  1800029999         Insertion Sort
# 14          14  1.152051      1128928  2450034999  Binary Insertion Sort
# 15          15  1.892463   2450034999  2450034999         Insertion Sort
# 16          16  2.110507      1308928  3200039999  Binary Insertion Sort
# 17          17  3.352235   3200039999  3200039999         Insertion Sort
# 18          18  3.202680      1488928  4050044999  Binary Insertion Sort
# 19          19  4.724854   4050044999  4050044999         Insertion Sort
# 20          20  3.439885      1668928  5000049999  Binary Insertion Sort
# 21          21  4.744288   5000049999  5000049999         Insertion Sort
#
#     Tamanho            Distribuição
# 0      1000  inversamente_ordenados
# 1      1000  inversamente_ordenados
# 2     10000  inversamente_ordenados
# 3     10000  inversamente_ordenados
# 4     20000  inversamente_ordenados
# 5     20000  inversamente_ordenados
# 6     30000  inversamente_ordenados
# 7     30000  inversamente_ordenados
# 8     40000  inversamente_ordenados
# 9     40000  inversamente_ordenados
# 10    50000  inversamente_ordenados
# 11    50000  inversamente_ordenados
# 12    60000  inversamente_ordenados
# 13    60000  inversamente_ordenados
# 14    70000  inversamente_ordenados
# 15    70000  inversamente_ordenados
# 16    80000  inversamente_ordenados
# 17    80000  inversamente_ordenados
# 18    90000  inversamente_ordenados
# 19    90000  inversamente_ordenados
# 20   100000  inversamente_ordenados
# 21   100000  inversamente_ordenados

# %% [markdown]
# #### Tempo de execução dos algoritmos de ordenação em diferentes tamanhos de entrada

# %%
sns.lineplot(x = "Tamanho", y = "tempo",
             hue = "Algoritmo", style = "Distribuição",
             data = df)
# Out:
# <Axes: xlabel='Tamanho', ylabel='tempo'>
